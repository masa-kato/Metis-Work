# %% [markdown]
# # Data Analysis

# %% [markdown]
# **Import Libraries**

# %%
# Import Relevant Libraries
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import scale

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
# Import Relevant Libraries
import sys
# Add Path to Project Files 
sys.path.append('/Users/Masa/Documents/Data Science/Metis/6. Projects/Project-McNulty/python')
sys.path.append('/Users/Masa/Documents/Data Science/Metis/6. Projects/Project-McNulty/python/mklearn')

# %% [markdown]
# **Import Project Python Modules**

# %%
# Import Python File
import data_visualization as dv
import data_import as di
from mklearn.mklearn import KNearestNeighbors_MK

# %% [markdown]
# ## Import Data

# %% [markdown]
# **Import Labeled Data**

# %%
df = di.create_dataframe()

# %%
# Preview Data
df.head(n=3)
# Out:
#    Labels    0    1    2    3    4    5    6    7    8  ...   3062  3063  \
# 0       6   59   43   50   68   98  119  139  145  149  ...     59    58
# 1       9  154  126  105  102  125  155  172  180  142  ...     22    42
# 2       9  255  253  253  253  253  253  253  253  253  ...     78    83
#
#    3064  3065  3066  3067  3068  3069  3070  3071
# 0    65    59    46    57   104   140    84    72
# 1    67   101   122   133   136   139   142   144
# 2    80    69    66    72    79    83    83    84
#
# [3 rows x 3073 columns]

# %%
df_sorted = df.sort_values(by='Labels').reset_index(drop=True)

# %%
# Preview Data
df_sorted.head(n=3)
# Out:
#    Labels    0    1    2    3    4    5    6    7    8  ...   3062  3063  \
# 0       0  112  109  108  106  102   99   99   99   99  ...     35    45
# 1       0  184  182  182  184  185  186  186  187  187  ...    139   139
# 2       0  202  200  200  200  200  200  200  201  201  ...     76    74
#
#    3064  3065  3066  3067  3068  3069  3070  3071
# 0    63    80    70    61    62    60    74    89
# 1   138   134   133   133   133   133   133   136
# 2    74    76    77    77    74    74    74    75
#
# [3 rows x 3073 columns]

# %% [markdown]
# **Target Classes**

# %%
classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

# %% [markdown]
# **Define X (Features) & Y (Target)**

# %%
X = df_sorted.iloc[:,1:]

# %%
y = df_sorted.iloc[:,0]

# %% [markdown]
# **Create RBF Arrays**

# %%
rbf = di.create_rbf_array(df)

# %%
rbf_sorted = di.create_rbf_array_sorted(df)

# %% [markdown]
# ## Preliminary Image Visualization

# %%
def visualize_random(matrix):
    '''
    Plots 100 Random Images from Dataset
    
    Input: 
        Numpy Array of RBF Pixels
    Output:
        Image Plots
    '''
    random_indices = np.random.choice(50000, 200)
    
    plt.figure(figsize=(20,10))
    for i in range(200):
        plt.subplot(10, 20, i+1)
        plt.imshow(matrix[random_indices[i]])
        plt.axis('off')

# %%
from PIL import Image
img = Image.open('../data/images/cow.jpg')
img.thumbnail((32, 32), Image.ANTIALIAS)
imgplot = plt.imshow(img)

# %%
img.save('../data/images/cow_resized.jpg')

# %%
from PIL import Image
img = Image.open('../data/images/bear.jpg')
img.thumbnail((32, 32), Image.ANTIALIAS)
imgplot = plt.imshow(img)

# %%
img.save('../data/images/bear_resized.jpg')

# %%
from PIL import Image
img = Image.open('../data/images/mow.jpg')
img.thumbnail((32, 32), Image.ANTIALIAS)
imgplot = plt.imshow(img)

# %%
img.save('../data/images/mow_resized.jpg')

# %%
from PIL import Image
img = Image.open('../data/images/trump.jpg')
img.thumbnail((32, 32), Image.ANTIALIAS)
imgplot = plt.imshow(img)

# %%
img.save('../data/images/trump_resized.jpg')

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[49],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[15024],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[20130],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[25305],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[30330],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[40026],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)

# %%
plt.figure(figsize=(4,4))
plt.imshow(rbf_sorted[1109],interpolation='gaussian')
plt.axis('off')
# Out:
# (-0.5, 31.5, 31.5, -0.5)
